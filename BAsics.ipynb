# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi16-ctrl/Learning-Python/blob/main/BAsics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+9
# Out:
# 11

# %%
print("Hello")
# Out:
# Hello

# %%
name= input("What is yourname")
# Out:
# What is yournameAditi

# %%
print("HAve a nice day", name)
# Out:
# HAve a nice day Aditi

# %%
exit()

# %%
myint=11
myfloat=12.2
mystr="I am"
mybool=True

# %%
print(myint)
# Out:
# 0

# %%
print(myint+myfloat)
# Out:
# 12.2

# %%
print(myint%2)
# Out:
# 1

# %%
print("nom"*3)
# Out:
# nomnomnom

# %%
print(myint==0)
# Out:
# False

# %%
#datatypes

# %%
#sequesnces
#list and tuples
#list[]
mylist=[1,"a",2.2]
print(len(mylist))
# Out:
# 3

# %%
print(mylist)
# Out:
# [1, 'a', 2.2]

# %%
print(mylist[2])
print(mylist[-1])
mylist[0]=4
# Out:
# 2.2
# 2.2

# %%
print(mylist)
# Out:
# [4, 'a', 2.2]

# %%
mylist2=[3,"er",4]

# %%
print(mylist[::2])
# Out:
# [4, 2.2]

# %%
print(mylist[::-1])
# Out:
# [2.2, 'a', 4]

# %%
mytuple=(0,1,"aaa") #immutable

# %%
print(mytuple)
# Out:
# (0, 1, 'aaa')

# %%
myset= {1,2,"a"}

# %%
print(myset)
#set and tuple donot use index
# Out:
# {1, 2, 'a'}

# %%
print(1 in mylist)
print(3 in myset)
# Out:
# False
# False

# %%
#dictionary datatype
mydict={
    "one": 1,
    "two":2,
    3:"three",
    4.5:"four"

}
print(mydict)
# Out:
# {'one': 1, 'two': 2, 3: 'three', 4.5: 'four'}

# %%
print(mydict["one"])
# Out:
# 1

# %%
print(mydict[3
])
# Out:
# three

# %%
mydict["seven"]=7
print(mydict)
# Out:
# {'one': 1, 'two': 2, 3: 'three', 4.5: 'four', 'seven': 7}

# %%
print(mydict["two"])
# Out:
# 2

# %%
print("two "in mydict)
# Out:
# False

# %%
print(mydict.keys())
print(mydict.values())
# Out:
# dict_keys(['one', 'two', 3, 4.5, 'seven'])
# dict_values([1, 2, 'three', 'four', 7])

# %%
for key, val in mydict.items():
  print(key,val)
# Out:
# one 1
# two 2
# 3 three
# 4.5 four
# seven 7

# %%
#conditional
x,y=100,100
if x<y:
  print("x is less than y")
elif x==y:
  print("same")
else:
  print("greater")
# Out:
# same

# %%
x=0
while x<5:
  print(x)
  x=x+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
answer =input("Stop")
while answer !="yes":
  answer =input("Stop")
#
# Out:
# Stopstop
# Stopno
# Stopyes

# %%
days=["mon","Tue","WEd","Thurs","Fri","sat","sun"]
for d in days:
  print(d)
# Out:
# mon
# Tue
# WEd
# Thurs
# Fri
# sat
# sun

# %%
for d in days:
  if(d=="WEd"):
    break
  print(d)
# Out:
# mon
# Tue

# %%
for d in days:
  if(d=="Fri"):
    continue
  print(d)
# Out:
# mon
# Tue
# WEd
# Thurs
# sat
# sun

# %%
for i, d in enumerate(days):
  print(i,d)
  #enumerate prints along with the index
# Out:
# 0 mon
# 1 Tue
# 2 WEd
# 3 Thurs
# 4 Fri
# 5 sat
# 6 sun

# %%
#definig function
def hello_fun():
  print("Hello")
  name= input("What is your name ")
  print("Have a nice day",name)
hello_fun()
# Out:
# Hello
# What is your name Aditi
# Have a nice day Aditi

# %%
#definig function
def hello_fun(greeting):
  print("Hello")
  name= input("What is your name ")
  print(greeting,name)
hello_fun("Have a nice day")
hello_fun("How you doing")
# Out:
# Hello
# What is your name Aditi
# Have a nice day Aditi
# Hello
# What is your name Aditi
# How you doing Aditi

# %%
#fucntion returns a value
def cube(x):
  return x*x*x
result=cube(3)
print(result)
# Out:
# 27

# %%
#default parameter
#definig function
def hello_fun(greeting, name=None):
  print("Hello")
  if name==None:
    name= input("What is your name ")
  print(greeting,name)
hello_fun("Have a nice  day", "Joe")
# Out:
# Hello
# Have a nice  day Joe

# %%
def multi_add(*args):
  result = 0
  for x in args:
    result=result+x
  return result
print(multi_add(5,4,3))
# Out:
# 12

# %%
#code challenge bumber counter
# Python code​​​​​​‌‌‌​‌​‌​​‌‌​‌‌​‌‌‌‌‌​​‌‌​ below
# Use print("messages...") to debug your solution.

show_expected_result = True
show_hints = True

def count_numbers(which, numbers):
    if which == "even":
        return sum(1 for num in numbers if num % 2 == 0)

    elif which == "odd":
        return sum(1 for num in numbers if num % 2 != 0)

    # Any other input re
    return -1

# %%
mystring="Brown lazy fox"
mynumbers=[1,2,3,4]
print(len(mystrinf))
print(max(mynumbers))
# Out:
# 14
# 4

# %%
print(min(mynumbers))
# Out:
# 1

# %%
prefix="ab"
result=8
print(prefix+str(3.4))
# Out:
# ab3.4

# %%
#range(start, stop, step)
for i in range(5,14,2):
  print(i)
# Out:
# 5
# 7
# 9
# 11
# 13

# %%
for i in range(5, len(mystring),2):
  print(mystring[i])
# Out:
#
# a
# y
# f
# x

# %%
def find_largest(strings):
    if not strings:
        return 0  # or None depending on assignment rules

    longest_length = 0

    for s in strings:
        if len(s) > longest_length:
            longest_length = len(s)

    return longest_length

# %%
class Vehicle:
  def __init__ (self,bodystyle):
    self.bodystyle=bodystyle
class Car(Vehicle):
  def __init__ (self, enginestyle):
    super().__init__("Car")
    self.wheels=4
    self.doors=4
    self.engine =enginestyle # Corrected: used enginestyle
class MOtor(Vehicle):
  def __init__(self, enginestyle, hassidecar): # Corrected: __intit__ to __init__ and added hassidecar parameter
    super().__init__("MOtor")
    if(hassidecar):
      self.wheels=3
    else:
      self.wheels=2
    self.doors=0
    self.enginetype =enginestyle # Corrected: used enginestyle
car1=Car("gas")
car2=Car("ele")
mc1=MOtor("gas", True)
print(mc1.wheels)
print(car1.engine)
print(car2.doors)
# Out:
# 3
# gas
# 4

# %%
#importing using modules
