# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi16-ctrl/Learning-Python/blob/main/Python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing modules
import math

# %%
print("square root", math.sqrt(16))
# Out:
# square root 4.0

# %%
from math import pi
print("Pi is", pi)
# Out:
# Pi is 3.141592653589793

# %%
import random as r
print(r.randint(100,200))
# Out:
# 178

# %%
from tabulate import tabulate

#tabulated data into format
data=[
    ["Product", "Price", "Stock"],
    ["Laptop",99.99,45],
    ["SmartPhone", 244,23]
]
print(tabulate(data, headers="firstrow", tablefmt="grid"))
# Out:
# +------------+---------+---------+
# | Product    |   Price |   Stock |
# +============+=========+=========+
# | Laptop     |   99.99 |      45 |
# +------------+---------+---------+
# | SmartPhone |  244    |      23 |
# +------------+---------+---------+

# %%
#using exceptions
try:
  x=10/0
except:
  print("WEll that didn't work")
# Out:
# WEll that didn't work

# %%
try:
  answer=input("What is the number")
  num=int(answer)
  print(10/num)
except ZeroDivisionError:
  print("You can't divide by zero")
except ValueError as e:
   print("Invalid input")
   print(e)
finally:
   print("finally always runs")
# Out:
# What is the number20
# 0.5
# finally always runs

# %%
#date, time, datetime
from datetime import date
from datetime import datetime
today=date.today()
print("Today dte is", today)
# Out:
# Today dte is 2025-11-24

# %%
print("date", today.day,today.month, today.year)
# Out:
# date 24 11 2025

# %%
print("Today's weekday", today.weekday()) #monday=0,  sunday=6
# Out:
# Today's weekday 0

# %%
today=datetime.now()
print("current date and time", today)
# Out:
# current date and time 2025-11-24 20:41:09.000997

# %%
t=datetime.time(datetime.now())
print("current time",t)
# Out:
# current time 20:41:55.083214

# %%
#using timedelta objects
from datetime import timedelta
from datetime import datetime
from datetime import date
print(timedelta(days=365, hours=5, minutes=1))
# Out:
# 365 days, 5:01:00

# %%
now=datetime.now()
print("Today", now)
print("Today in one year", now+timedelta(days=365))
print("Two weeks 3 days", now+timedelta(weeks=2,days=3))
# Out:
# Today 2025-11-24 20:46:17.442654
# Today in one year 2026-11-24 20:46:17.442654
# Two weeks 3 days 2025-12-11 20:46:17.442654

# %%
t=datetime.now()-timedelta(weeks=1)
s=t.strftime("%A %B %d %Y")
print("One week ago",s)
# Out:
# One week ago Monday November 17 2025

# %%
sample_file=open("textfile.txt","w+")
sample_file.write("sample text")
sample_file.close()

# %%
#opening file for appending text to the end withhout changing the format
sample_file=open("textfile.txt","a+") #a+ to append
sample_file.write("sample 2text")
sample_file.write("sample 3text")
sample_file.close()

# %%
#open the files and read content
sample_file=open("textfile.txt","r")
if sample_file.mode=="r":
  #contents=sample_file.read()
  #print(contents)
  file_lines =sample_file.readlines()
for line in file_lines:
  print(line)
# Out:
# sample textsample 2textsample 3text

# %%
#working with operating system
import os
import time
from datetime import date
print(os.name)
# Out:
# posix

# %%
from os import path
print("Items", path.exists("textfile.txt"))
print("Items is file", path.isfile("textfile.txt"))
print("Items is dir", path.isdir("textfile.txt"))
# Out:
# Items True
# Items is file True
# Items is dir False

# %%
print("Items's path", path.realpath("textfile.txt"))
print("Items's path and name", path.split(path.realpath("textfile.txt")))
# Out:
# Items's path /content/textfile.txt
# Items's path and name ('/content', 'textfile.txt')

# %%
import time
from os import path
from datetime import date
#modification time
t=time.ctime(path.getmtime("textfile.txt"))
print(t)
print(date.fromtimestamp(path.getatime("textfile.txt")))
# Out:
# Mon Nov 24 20:54:44 2025
# 2025-11-24

# %%
from datetime import datetime
from os import path
#calculate how lon time item was modified
td=datetime.now()-datetime.fromtimestamp(path.getmtime("textfile.txt"))
print(f"It has been {td} since file was modified")
print(f"Or , {td.total_seconds()} seconds")
# Out:
# It has been 0:14:30.079448 since file was modified
# Or , 870.079448 seconds

# %%
#using filesystem
import os
from os import pardir
import shutil
if path.exists("textfile.txt"):
  src=path.realpath("textfile.txt")#get the path to the file
  dst=src+".bak" #backup copy
  shutil.copy(src,dst) #use shell to make copy
os.rename("textfile.txt", "new.txt")

# %%
#putting things into zip archive
#using filesystem
import os
from os import pardir
import shutil
if path.exists("new.txt"):
  src=path.realpath("new.txt")#get the path to the file
root_dir, tail=path.split(src)
shutil.make_archive("archive","zip", root_dir)
# Out:
# '/content/archive.zip'

# %%
from zipfile import ZipFile #finegrained zip
with ZipFile("testzip.zip","w") as newzip:
  newzip.write("new.txt")
  newzip.write("textfile.txt.bak")

# %%
#retrive data from server/internet
import urllib.request
web_url=urllib.request.urlopen("https://www.google.com")
print("result code", web_url.getcode())
data=web_url.read()
print(data)
# Out:
# result code 200
# ...

# %%
import numpy
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import classification_report

data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/social.csv")
print(data.head())
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
x = np.array(data[["Age", "EstimatedSalary"]])
y = np.array(data[["Purchased"]])

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.10, random_state=42)
decisiontree = DecisionTreeClassifier()
logisticregression = LogisticRegression()
knearestclassifier = KNeighborsClassifier()
bernoulli_naiveBayes = BernoulliNB()
passiveAggressive = PassiveAggressiveClassifier()

knearestclassifier.fit(xtrain, ytrain)
decisiontree.fit(xtrain, ytrain)
logisticregression.fit(xtrain, ytrain)
passiveAggressive.fit(xtrain, ytrain)

data1 = {"Classification Algorithms": ["KNN Classifier", "Decision Tree Classifier",
                                       "Logistic Regression", "Passive Aggressive Classifier"],
      "Score": [knearestclassifier.score(x,y), decisiontree.score(x, y),
                logisticregression.score(x, y), passiveAggressive.score(x,y) ]}
score = pd.DataFrame(data1)
score
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#        Classification Algorithms   Score
# 0                 KNN Classifier  0.8750
# 1       Decision Tree Classifier  0.9800
# 2            Logistic Regression  0.8400
# ...
